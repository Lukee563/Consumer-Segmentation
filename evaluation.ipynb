# %% [markdown]
# ## Now that we know clustering is possible, and balanced cluster groups exist naturally within the data, it is best practice to mathematically assess the stability of these clusters, and the optimal amount of clusters we should create

# %%
from methods.cluster_evaluation import evaluate_clusters

# Run clustering algorithm and assign clusters to our consumers
path = "data/coffee_survey.csv"
max_k = 10

eval = evaluate_clusters(path, max_k)
# Out:
# Evaluating clusters for k = 2 to 10...
# k=2: Cost=58557, Silhouette=0.0710
# k=3: Cost=56937, Silhouette=0.0450
# k=4: Cost=55695, Silhouette=0.0386
# k=5: Cost=54924, Silhouette=0.0246
# k=6: Cost=54252, Silhouette=0.0218
# k=7: Cost=53910, Silhouette=0.0222
# k=8: Cost=53335, Silhouette=0.0177
# k=9: Cost=52937, Silhouette=0.0132
# k=10: Cost=52432, Silhouette=0.0172

# %%
from methods.cluster_evaluation import evaluate_stability
# Run clustering algorithm and assign clusters to our consumers
path = "data/coffee_survey.csv"
k = 4

eval = evaluate_stability(path, k)
# Out:
# Testing stability for k=4 over 20 runs...
# Mean Cost: 55723 | Std Dev: 78
